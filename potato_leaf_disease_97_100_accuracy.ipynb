# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES
# TO THE CORRECT LOCATION (/kaggle/input) IN YOUR NOTEBOOK,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

import os
import sys
from tempfile import NamedTemporaryFile
from urllib.request import urlopen
from urllib.parse import unquote, urlparse
from urllib.error import HTTPError
from zipfile import ZipFile
import tarfile
import shutil

CHUNK_SIZE = 40960
DATA_SOURCE_MAPPING = 'plant-village:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F414960%2F793497%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240721%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240721T084537Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...'

KAGGLE_INPUT_PATH='/kaggle/input'
KAGGLE_WORKING_PATH='/kaggle/working'
KAGGLE_SYMLINK='kaggle'

# !umount /kaggle/input/ 2> /dev/null
shutil.rmtree('/kaggle/input', ignore_errors=True)
os.makedirs(KAGGLE_INPUT_PATH, 0o777, exist_ok=True)
os.makedirs(KAGGLE_WORKING_PATH, 0o777, exist_ok=True)

try:
  os.symlink(KAGGLE_INPUT_PATH, os.path.join("..", 'input'), target_is_directory=True)
except FileExistsError:
  pass
try:
  os.symlink(KAGGLE_WORKING_PATH, os.path.join("..", 'working'), target_is_directory=True)
except FileExistsError:
  pass

for data_source_mapping in DATA_SOURCE_MAPPING.split(','):
    directory, download_url_encoded = data_source_mapping.split(':')
    download_url = unquote(download_url_encoded)
    filename = urlparse(download_url).path
    destination_path = os.path.join(KAGGLE_INPUT_PATH, directory)
    try:
        with urlopen(download_url) as fileres, NamedTemporaryFile() as tfile:
            total_length = fileres.headers['content-length']
            print(f'Downloading {directory}, {total_length} bytes compressed')
            dl = 0
            data = fileres.read(CHUNK_SIZE)
            while len(data) > 0:
                dl += len(data)
                tfile.write(data)
                done = int(50 * dl / int(total_length))
                sys.stdout.write(f"\r[{'=' * done}{' ' * (50-done)}] {dl} bytes downloaded")
                sys.stdout.flush()
                data = fileres.read(CHUNK_SIZE)
            if filename.endswith('.zip'):
              with ZipFile(tfile) as zfile:
                zfile.extractall(destination_path)
            else:
              with tarfile.open(tfile.name) as tarfile:
                tarfile.extractall(destination_path)
            print(f'\nDownloaded and uncompressed: {directory}')
    except HTTPError as e:
        print(f'Failed to load (likely expired) {download_url} to path {destination_path}')
        continue
    except OSError as e:
        print(f'Failed to load {download_url} to path {destination_path}')
        continue

print('Data source import complete.')
# Out:
# Downloading plant-village, 344488049 bytes compressed
# [==================================================] 344488049 bytes downloaded
# Downloaded and uncompressed: plant-village
# Data source import complete.

# %% [markdown]
# # Problem Statement
# Farmers every year face economic loss and crop waste due to various diseases in potato plants.  Early blight and Late blight are major disease of potato leaf. It is estimated that the major loss occurred in potato yield is due to these diseases. Thus the images are classified into 3 classes :
# - Healthy leaves
# <img src="https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse1.mm.bing.net%2Fth%3Fid%3DOIP.jW152ASG2nfRv_LCkYnzMQHaFj%26pid%3DApi&f=1" height='200' width="300"/>
#
# - Late Blight leaves
# <img src="https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse2.mm.bing.net%2Fth%3Fid%3DOIP.vCrNUKDj1Z1zErHEMQzmCQHaFj%26pid%3DApi&f=1" height='200' width="300"/>
#
# - Early Blight leaves
# <img src="https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse2.mm.bing.net%2Fth%3Fid%3DOIP.e4wvw_JVbE1yFgOYbUoVSAHaE7%26pid%3DApi&f=1" height='200' width="300"/>
#
# Project inspiration : https://youtube.com/playlist?list=PLeo1K3hjS3utJFNGyBpIvjWgSDY0eOE8S

# %%
# import libraries
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
import numpy as np
import pathlib
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' # to disable all debugging logs

# %%
import os
import zipfile

# Path to the ZIP file
dataset_path = '/content/archive (2).zip'
extract_path = '/content/extracted_files'

# Extract the ZIP file
with zipfile.ZipFile(dataset_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# List the contents of the extracted directory
extracted_contents = os.listdir(extract_path)
print("Extracted contents:", extracted_contents)

# Iterate over the extracted contents and print filenames
for root, dirs, files in os.walk(extract_path):
    print(f"Root: {root}")
    print(f"Directories: {dirs}")
    print(f"Files: {files}")
    print("-" * 20)
# Out:
# Extracted contents: ['PLD_3_Classes_256']
# Root: /content/extracted_files
# Directories: ['PLD_3_Classes_256']
# Files: []
# --------------------
# Root: /content/extracted_files/PLD_3_Classes_256
# Directories: ['Validation', 'Testing', 'Training']
# Files: []
# --------------------
# Root: /content/extracted_files/PLD_3_Classes_256/Validation
# Directories: ['Healthy', 'Late_Blight', 'Early_Blight']
# Files: []
# --------------------
# Root: /content/extracted_files/PLD_3_Classes_256/Validation/Healthy
# Directories: []
# Files: ['Healthy_80.jpg', 'Healthy_26.jpg', 'Healthy_2.jpg', 'Healthy_19.jpg', 'Healthy_55.jpg', 'Healthy_28.jpg', 'Healthy_81.jpg', 'Healthy_61.jpg', 'Healthy_93.jpg', 'Healthy_12.jpg', 'Healthy_72.jpg', 'Healthy_49.jpg', 'Healthy_23.jpg', 'Healthy_17.jpg', 'Healthy_79.jpg', 'Healthy_30.jpg', 'Healthy_65.jpg', 'Healthy_60.jpg', 'Healthy_76.jpg', 'Healthy_63.jpg', 'Healthy_13.jpg', 'Healthy_66.jpg', 'Healthy_46.jpg', 'Healthy_37.jpg', 'Healthy_90.jpg', 'Healthy_89.jpg', 'Healthy_97.jpg', 'Healthy_51.jpg', 'Healthy_85.jpg', 'Healthy_78.jpg', 'Healthy_101.jpg', 'Healthy_56.jpg', 'Healthy_52.jpg', 'Healthy_4.jpg', 'Healthy_58.jpg', 'Healthy_100.jpg', 'Healthy_33.jpg', 'Healthy_1.jpg', 'Healthy_32.jpg', 'Healthy_73.jpg', 'Healthy_11.jpg', 'Healthy_10.jpg', 'Healthy_50.jpg', 'Healthy_27.jpg', 'Healthy_39.jpg', 'Healthy_99.jpg', 'Healthy_69.jpg', 'Healthy_67.jpg', 'Healthy_54.jpg', 'Healthy_95.jpg', 'Healthy_59.jpg', 'Healthy_38.jpg', 'Healthy_35.jpg', 'Healthy_21.jpg', 'Healthy_31.jpg', 'Healthy_88.jpg', 'Healthy_47.jpg', 'Healthy_15.jpg', 'Healthy_87.jpg', 'Healthy_74.jpg', 'Healthy_77.jpg', 'Healthy_68.jpg', 'Healthy_84.jpg', 'Healthy_36.jpg', 'Healthy_82.jpg', 'Healthy_9.jpg', 'Healthy_75.jpg', 'Healthy_3.jpg', 'Healthy_70.jpg', 'Healthy_34.jpg', 'Healthy_96.jpg', 'Healthy_8.jpg', 'Healthy_71.jpg', 'Healthy_24.jpg', 'Healthy_98.jpg', 'Healthy_41.jpg', 'Healthy_64.jpg', 'Healthy_102.jpg', 'Healthy_57.jpg', 'Healthy_83.jpg', 'Healthy_7.jpg', 'Healthy_92.jpg', 'Healthy_22.jpg', 'Healthy_91.jpg', 'Healthy_94.jpg', 'Healthy_42.jpg', 'Healthy_18.jpg', 'Healthy_14.jpg', 'Healthy_40.jpg', 'Healthy_6.jpg', 'Healthy_45.jpg', 'Healthy_86.jpg', 'Healthy_16.jpg', 'Healthy_53.jpg', 'Healthy_20.jpg', 'Healthy_44.jpg', 'Healthy_29.jpg', 'Healthy_25.jpg', 'Healthy_62.jpg', 'Healthy_5.jpg', 'Healthy_43.jpg', 'Healthy_48.jpg']
# --------------------
# Root: /content/extracted_files/PLD_3_Classes_256/Validation/Late_Blight
# Directories: []
# Files: ['Late_Blight_94.jpg', 'Late_Blight_87.jpg', 'Late_Blight_65.jpg', 'Late_Blight_83.jpg', 'Late_Blight_17.jpg', 'Late_Blight_43.jpg', 'Late_Blight_114.jpg', 'Late_Blight_136.jpg', 'Late_Blight_71.jpg', 'Late_Blight_46.jpg', 'Late_Blight_101.jpg', 'Late_Blight_16.jpg', 'Late_Blight_48.jpg', 'Late_Blight_13.jpg', 'Late_Blight_27.jpg', 'Late_Blight_25.jpg', 'Late_Blight_70.jpg', 'Late_Blight_60.jpg', 'Late_Blight_36.jpg', 'Late_Blight_81.jpg', 'Late_Blight_79.jpg', 'Late_Blight_88.jpg', 'Late_Blight_107.jpg', 'Late_Blight_109.jpg', 'Late_Blight_4.jpg', 'Late_Blight_108.jpg', 'Late_Blight_50.jpg', 'Late_Blight_35(1).jpg', 'Late_Blight_22.jpg', 'Late_Blight_58.jpg', 'Late_Blight_32.jpg', 'Late_Blight_68.jpg', 'Late_Blight_77.jpg', 'Late_Blight_103.jpg', 'Late_Blight_21.jpg', 'Late_Blight_59.jpg', 'Late_Blight_52.jpg', 'Late_Blight_80.jpg', 'Late_Blight_19.jpg', 'Late_Blight_10.jpg', 'Late_Blight_123.jpg', 'Late_Blight_44.jpg', 'Late_Blight_5.jpg', 'Late_Blight_90.jpg', 'Late_Blight_47.jpg', 'Late_Blight_127.jpg', 'Late_Blight_73.jpg', 'Late_Blight_120.jpg', 'Late_Blight_89.jpg', 'Late_Blight_69.jpg', 'Late_Blight_134.jpg', 'Late_Blight_23.jpg', 'Late_Blight_42.jpg', 'Late_Blight_130.jpg', 'Late_Blight_86.jpg', 'Late_Blight_140.jpg', 'Late_Blight_56.jpg', 'Late_Blight_97.jpg', 'Late_Blight_74.jpg', 'Late_Blight_125.jpg', 'Late_Blight_42(1).jpg', 'Late_Blight_62.jpg', 'Late_Blight_12.jpg', 'Late_Blight_55.jpg', 'Late_Blight_61.jpg', 'Late_Blight_115.jpg', 'Late_Blight_76.jpg', 'Late_Blight_137.jpg', 'Late_Blight_121.jpg', 'Late_Blight_92.jpg', 'Late_Blight_104.jpg', 'Late_Blight_84.jpg', 'Late_Blight_138.jpg', 'Late_Blight_135.jpg', 'Late_Blight_8.jpg', 'Late_Blight_38(1).jpg', 'Late_Blight_72.jpg', 'Late_Blight_51.jpg', 'Late_Blight_93.jpg', 'Late_Blight_30.jpg', 'Late_Blight_98.jpg', 'Late_Blight_118.jpg', 'Late_Blight_96.jpg', 'Late_Blight_99.jpg', 'Late_Blight_34.jpg', 'Late_Blight_2.jpg', 'Late_Blight_14.jpg', 'Late_Blight_39(1).jpg', 'Late_Blight_29.jpg', 'Late_Blight_119.jpg', 'Late_Blight_3.jpg', 'Late_Blight_4(1).jpg', 'Late_Blight_110.jpg', 'Late_Blight_11.jpg', 'Late_Blight_6.jpg', 'Late_Blight_39.jpg', 'Late_Blight_53.jpg', 'Late_Blight_40(1).jpg', 'Late_Blight_45.jpg', 'Late_Blight_38.jpg', 'Late_Blight_133.jpg', 'Late_Blight_116.jpg', 'Late_Blight_35.jpg', 'Late_Blight_36(1).jpg', 'Late_Blight_33.jpg', 'Late_Blight_113.jpg', 'Late_Blight_28.jpg', 'Late_Blight_64.jpg', 'Late_Blight_78.jpg', 'Late_Blight_141.jpg', 'Late_Blight_100.jpg', 'Late_Blight_49.jpg', 'Late_Blight_106.jpg', 'Late_Blight_57.jpg', 'Late_Blight_1.jpg', 'Late_Blight_26.jpg', 'Late_Blight_85.jpg', 'Late_Blight_54.jpg', 'Late_Blight_37.jpg', 'Late_Blight_95.jpg', 'Late_Blight_37(1).jpg', 'Late_Blight_126.jpg', 'Late_Blight_139.jpg', 'Late_Blight_43(1).jpg', 'Late_Blight_91.jpg', 'Late_Blight_41(1).jpg', 'Late_Blight_112.jpg', 'Late_Blight_18.jpg', 'Late_Blight_20.jpg', 'Late_Blight_15.jpg', 'Late_Blight_131.jpg', 'Late_Blight_31.jpg', 'Late_Blight_75.jpg', 'Late_Blight_9.jpg', 'Late_Blight_129.jpg', 'Late_Blight_132.jpg', 'Late_Blight_128.jpg', 'Late_Blight_67.jpg', 'Late_Blight_111.jpg', 'Late_Blight_102.jpg', 'Late_Blight_122.jpg', 'Late_Blight_7.jpg', 'Late_Blight_124.jpg', 'Late_Blight_82.jpg', 'Late_Blight_41.jpg', 'Late_Blight_105.jpg', 'Late_Blight_66.jpg', 'Late_Blight_63.jpg', 'Late_Blight_117.jpg', 'Late_Blight_24.jpg', 'Late_Blight_40.jpg']
# --------------------
# Root: /content/extracted_files/PLD_3_Classes_256/Validation/Early_Blight
# Directories: []
# Files: ['Early_Blight_116.jpg', 'Early_Blight_83.jpg', 'Early_Blight_35.jpg', 'Early_Blight_13.jpg', 'Early_Blight_157.jpg', 'Early_Blight_4.jpg', 'Early_Blight_89.jpg', 'Early_Blight_139.jpg', 'Early_Blight_123.jpg', 'Early_Blight_107.jpg', 'Early_Blight_27.jpg', 'Early_Blight_82.jpg', 'Early_Blight_1.jpg', 'Early_Blight_121.jpg', 'Early_Blight_114.jpg', 'Early_Blight_44.jpg', 'Early_Blight_29.jpg', 'Early_Blight_20.jpg', 'Early_Blight_129.jpg', 'Early_Blight_73.jpg', 'Early_Blight_81.jpg', 'Early_Blight_137.jpg', 'Early_Blight_140.jpg', 'Early_Blight_26.jpg', 'Early_Blight_118.jpg', 'Early_Blight_112.jpg', 'Early_Blight_125.jpg', 'Early_Blight_61.jpg', 'Early_Blight_133.jpg', 'Early_Blight_32.jpg', 'Early_Blight_102.jpg', 'Early_Blight_46.jpg', 'Early_Blight_69.jpg', 'Early_Blight_19.jpg', 'Early_Blight_70.jpg', 'Early_Blight_109.jpg', 'Early_Blight_99.jpg', 'Early_Blight_22.jpg', 'Early_Blight_156.jpg', 'Early_Blight_50.jpg', 'Early_Blight_144.jpg', 'Early_Blight_95.jpg', 'Early_Blight_15.jpg', 'Early_Blight_98.jpg', 'Early_Blight_119.jpg', 'Early_Blight_158.jpg', 'Early_Blight_31.jpg', 'Early_Blight_80.jpg', 'Early_Blight_153.jpg', 'Early_Blight_152.jpg', 'Early_Blight_71.jpg', 'Early_Blight_5.jpg', 'Early_Blight_120.jpg', 'Early_Blight_85.jpg', 'Early_Blight_14.jpg', 'Early_Blight_28.jpg', 'Early_Blight_104.jpg', 'Early_Blight_72.jpg', 'Early_Blight_94.jpg', 'Early_Blight_67.jpg', 'Early_Blight_159.jpg', 'Early_Blight_150.jpg', 'Early_Blight_8.jpg', 'Early_Blight_154.jpg', 'Early_Blight_163.jpg', 'Early_Blight_97.jpg', 'Early_Blight_87.jpg', 'Early_Blight_24.jpg', 'Early_Blight_132.jpg', 'Early_Blight_136.jpg', 'Early_Blight_134.jpg', 'Early_Blight_84.jpg', 'Early_Blight_65.jpg', 'Early_Blight_53.jpg', 'Early_Blight_128.jpg', 'Early_Blight_55.jpg', 'Early_Blight_91.jpg', 'Early_Blight_131.jpg', 'Early_Blight_58.jpg', 'Early_Blight_135.jpg', 'Early_Blight_17.jpg', 'Early_Blight_25.jpg', 'Early_Blight_105.jpg', 'Early_Blight_141.jpg', 'Early_Blight_57.jpg', 'Early_Blight_18.jpg', 'Early_Blight_56.jpg', 'Early_Blight_54.jpg', 'Early_Blight_77.jpg', 'Early_Blight_47.jpg', 'Early_Blight_117.jpg', 'Early_Blight_124.jpg', 'Early_Blight_86.jpg', 'Early_Blight_161.jpg', 'Early_Blight_9.jpg', 'Early_Blight_90.jpg', 'Early_Blight_78.jpg', 'Early_Blight_147.jpg', 'Early_Blight_101.jpg', 'Early_Blight_60.jpg', 'Early_Blight_113.jpg', 'Early_Blight_45.jpg', 'Early_Blight_110.jpg', 'Early_Blight_37.jpg', 'Early_Blight_62.jpg', 'Early_Blight_51.jpg', 'Early_Blight_11.jpg', 'Early_Blight_127.jpg', 'Early_Blight_76.jpg', 'Early_Blight_23.jpg', 'Early_Blight_149.jpg', 'Early_Blight_151.jpg', 'Early_Blight_93.jpg', 'Early_Blight_48.jpg', 'Early_Blight_6.jpg', 'Early_Blight_155.jpg', 'Early_Blight_100.jpg', 'Early_Blight_64.jpg', 'Early_Blight_142.jpg', 'Early_Blight_122.jpg', 'Early_Blight_111.jpg', 'Early_Blight_30.jpg', 'Early_Blight_143.jpg', 'Early_Blight_96.jpg', 'Early_Blight_126.jpg', 'Early_Blight_3.jpg', 'Early_Blight_42.jpg', 'Early_Blight_33.jpg', 'Early_Blight_2.jpg', 'Early_Blight_106.jpg', 'Early_Blight_88.jpg', 'Early_Blight_12.jpg', 'Early_Blight_63.jpg', 'Early_Blight_43.jpg', 'Early_Blight_39.jpg', 'Early_Blight_40.jpg', 'Early_Blight_66.jpg', 'Early_Blight_49.jpg', 'Early_Blight_38.jpg', 'Early_Blight_52.jpg', 'Early_Blight_79.jpg', 'Early_Blight_59.jpg', 'Early_Blight_74.jpg', 'Early_Blight_115.jpg', 'Early_Blight_162.jpg', 'Early_Blight_10.jpg', 'Early_Blight_138.jpg', 'Early_Blight_16.jpg', 'Early_Blight_145.jpg', 'Early_Blight_34.jpg', 'Early_Blight_130.jpg', 'Early_Blight_148.jpg', 'Early_Blight_92.jpg', 'Early_Blight_7.jpg', 'Early_Blight_36.jpg', 'Early_Blight_68.jpg', 'Early_Blight_21.jpg', 'Early_Blight_103.jpg', 'Early_Blight_75.jpg', 'Early_Blight_146.jpg', 'Early_Blight_108.jpg', 'Early_Blight_160.jpg', 'Early_Blight_41.jpg']
# --------------------
# Root: /content/extracted_files/PLD_3_Classes_256/Testing
# Directories: ['Healthy', 'Late_Blight', 'Early_Blight']
# Files: []
# --------------------
# Root: /content/extracted_files/PLD_3_Classes_256/Testing/Healthy
# Directories: []
# Files: ['Healthy_80.jpg', 'Healthy_26.jpg', 'Healthy_2.jpg', 'Healthy_19.jpg', 'Healthy_55.jpg', 'Healthy_28.jpg', 'Healthy_81.jpg', 'Healthy_61.jpg', 'Healthy_93.jpg', 'Healthy_12.jpg', 'Healthy_72.jpg', 'Healthy_49.jpg', 'Healthy_23.jpg', 'Healthy_17.jpg', 'Healthy_79.jpg', 'Healthy_30.jpg', 'Healthy_65.jpg', 'Healthy_60.jpg', 'Healthy_76.jpg', 'Healthy_63.jpg', 'Healthy_13.jpg', 'Healthy_66.jpg', 'Healthy_46.jpg', 'Healthy_37.jpg', 'Healthy_90.jpg', 'Healthy_89.jpg', 'Healthy_97.jpg', 'Healthy_51.jpg', 'Healthy_85.jpg', 'Healthy_78.jpg', 'Healthy_101.jpg', 'Healthy_56.jpg', 'Healthy_52.jpg', 'Healthy_4.jpg', 'Healthy_58.jpg', 'Healthy_100.jpg', 'Healthy_33.jpg', 'Healthy_1.jpg', 'Healthy_32.jpg', 'Healthy_73.jpg', 'Healthy_11.jpg', 'Healthy_10.jpg', 'Healthy_50.jpg', 'Healthy_27.jpg', 'Healthy_39.jpg', 'Healthy_99.jpg', 'Healthy_69.jpg', 'Healthy_67.jpg', 'Healthy_54.jpg', 'Healthy_95.jpg', 'Healthy_59.jpg', 'Healthy_38.jpg', 'Healthy_35.jpg', 'Healthy_21.jpg', 'Healthy_31.jpg', 'Healthy_88.jpg', 'Healthy_47.jpg', 'Healthy_15.jpg', 'Healthy_87.jpg', 'Healthy_74.jpg', 'Healthy_77.jpg', 'Healthy_68.jpg', 'Healthy_84.jpg', 'Healthy_36.jpg', 'Healthy_82.jpg', 'Healthy_9.jpg', 'Healthy_75.jpg', 'Healthy_3.jpg', 'Healthy_70.jpg', 'Healthy_34.jpg', 'Healthy_96.jpg', 'Healthy_8.jpg', 'Healthy_71.jpg', 'Healthy_24.jpg', 'Healthy_98.jpg', 'Healthy_41.jpg', 'Healthy_64.jpg', 'Healthy_102.jpg', 'Healthy_57.jpg', 'Healthy_83.jpg', 'Healthy_7.jpg', 'Healthy_92.jpg', 'Healthy_22.jpg', 'Healthy_91.jpg', 'Healthy_94.jpg', 'Healthy_42.jpg', 'Healthy_18.jpg', 'Healthy_14.jpg', 'Healthy_40.jpg', 'Healthy_6.jpg', 'Healthy_45.jpg', 'Healthy_86.jpg', 'Healthy_16.jpg', 'Healthy_53.jpg', 'Healthy_20.jpg', 'Healthy_44.jpg', 'Healthy_29.jpg', 'Healthy_25.jpg', 'Healthy_62.jpg', 'Healthy_5.jpg', 'Healthy_43.jpg', 'Healthy_48.jpg']
# --------------------
# Root: /content/extracted_files/PLD_3_Classes_256/Testing/Late_Blight
# Directories: []
# Files: ['Late_Blight_94.jpg', 'Late_Blight_87.jpg', 'Late_Blight_65.jpg', 'Late_Blight_83.jpg', 'Late_Blight_17.jpg', 'Late_Blight_43.jpg', 'Late_Blight_114.jpg', 'Late_Blight_136.jpg', 'Late_Blight_71.jpg', 'Late_Blight_46.jpg', 'Late_Blight_101.jpg', 'Late_Blight_16.jpg', 'Late_Blight_48.jpg', 'Late_Blight_13.jpg', 'Late_Blight_27.jpg', 'Late_Blight_25.jpg', 'Late_Blight_70.jpg', 'Late_Blight_60.jpg', 'Late_Blight_36.jpg', 'Late_Blight_81.jpg', 'Late_Blight_79.jpg', 'Late_Blight_88.jpg', 'Late_Blight_107.jpg', 'Late_Blight_109.jpg', 'Late_Blight_4.jpg', 'Late_Blight_108.jpg', 'Late_Blight_50.jpg', 'Late_Blight_22.jpg', 'Late_Blight_58.jpg', 'Late_Blight_32.jpg', 'Late_Blight_68.jpg', 'Late_Blight_77.jpg', 'Late_Blight_103.jpg', 'Late_Blight_21.jpg', 'Late_Blight_59.jpg', 'Late_Blight_52.jpg', 'Late_Blight_80.jpg', 'Late_Blight_19.jpg', 'Late_Blight_10.jpg', 'Late_Blight_123.jpg', 'Late_Blight_44.jpg', 'Late_Blight_5.jpg', 'Late_Blight_90.jpg', 'Late_Blight_47.jpg', 'Late_Blight_127.jpg', 'Late_Blight_73.jpg', 'Late_Blight_120.jpg', 'Late_Blight_89.jpg', 'Late_Blight_69.jpg', 'Late_Blight_134.jpg', 'Late_Blight_23.jpg', 'Late_Blight_42.jpg', 'Late_Blight_130.jpg', 'Late_Blight_86.jpg', 'Late_Blight_140.jpg', 'Late_Blight_56.jpg', 'Late_Blight_97.jpg', 'Late_Blight_74.jpg', 'Late_Blight_125.jpg', 'Late_Blight_62.jpg', 'Late_Blight_12.jpg', 'Late_Blight_55.jpg', 'Late_Blight_61.jpg', 'Late_Blight_115.jpg', 'Late_Blight_76.jpg', 'Late_Blight_137.jpg', 'Late_Blight_121.jpg', 'Late_Blight_92.jpg', 'Late_Blight_104.jpg', 'Late_Blight_84.jpg', 'Late_Blight_138.jpg', 'Late_Blight_135.jpg', 'Late_Blight_8.jpg', 'Late_Blight_72.jpg', 'Late_Blight_51.jpg', 'Late_Blight_93.jpg', 'Late_Blight_30.jpg', 'Late_Blight_98.jpg', 'Late_Blight_118.jpg', 'Late_Blight_96.jpg', 'Late_Blight_99.jpg', 'Late_Blight_34.jpg', 'Late_Blight_2.jpg', 'Late_Blight_14.jpg', 'Late_Blight_29.jpg', 'Late_Blight_119.jpg', 'Late_Blight_3.jpg', 'Late_Blight_110.jpg', 'Late_Blight_11.jpg', 'Late_Blight_6.jpg', 'Late_Blight_39.jpg', 'Late_Blight_53.jpg', 'Late_Blight_45.jpg', 'Late_Blight_38.jpg', 'Late_Blight_133.jpg', 'Late_Blight_116.jpg', 'Late_Blight_35.jpg', 'Late_Blight_33.jpg', 'Late_Blight_113.jpg', 'Late_Blight_28.jpg', 'Late_Blight_64.jpg', 'Late_Blight_78.jpg', 'Late_Blight_141.jpg', 'Late_Blight_100.jpg', 'Late_Blight_49.jpg', 'Late_Blight_106.jpg', 'Late_Blight_57.jpg', 'Late_Blight_1.jpg', 'Late_Blight_26.jpg', 'Late_Blight_85.jpg', 'Late_Blight_54.jpg', 'Late_Blight_37.jpg', 'Late_Blight_95.jpg', 'Late_Blight_126.jpg', 'Late_Blight_139.jpg', 'Late_Blight_91.jpg', 'Late_Blight_112.jpg', 'Late_Blight_18.jpg', 'Late_Blight_20.jpg', 'Late_Blight_15.jpg', 'Late_Blight_131.jpg', 'Late_Blight_31.jpg', 'Late_Blight_75.jpg', 'Late_Blight_9.jpg', 'Late_Blight_129.jpg', 'Late_Blight_132.jpg', 'Late_Blight_128.jpg', 'Late_Blight_67.jpg', 'Late_Blight_111.jpg', 'Late_Blight_102.jpg', 'Late_Blight_122.jpg', 'Late_Blight_7.jpg', 'Late_Blight_124.jpg', 'Late_Blight_82.jpg', 'Late_Blight_41.jpg', 'Late_Blight_105.jpg', 'Late_Blight_66.jpg', 'Late_Blight_63.jpg', 'Late_Blight_117.jpg', 'Late_Blight_24.jpg', 'Late_Blight_40.jpg']
# --------------------
# Root: /content/extracted_files/PLD_3_Classes_256/Testing/Early_Blight
# Directories: []
# Files: ['Early_Blight_116.jpg', 'Early_Blight_83.jpg', 'Early_Blight_35.jpg', 'Early_Blight_13.jpg', 'Early_Blight_157.jpg', 'Early_Blight_4.jpg', 'Early_Blight_89.jpg', 'Early_Blight_139.jpg', 'Early_Blight_123.jpg', 'Early_Blight_107.jpg', 'Early_Blight_27.jpg', 'Early_Blight_82.jpg', 'Early_Blight_1.jpg', 'Early_Blight_121.jpg', 'Early_Blight_114.jpg', 'Early_Blight_44.jpg', 'Early_Blight_29.jpg', 'Early_Blight_20.jpg', 'Early_Blight_129.jpg', 'Early_Blight_73.jpg', 'Early_Blight_81.jpg', 'Early_Blight_137.jpg', 'Early_Blight_140.jpg', 'Early_Blight_26.jpg', 'Early_Blight_118.jpg', 'Early_Blight_112.jpg', 'Early_Blight_125.jpg', 'Early_Blight_61.jpg', 'Early_Blight_133.jpg', 'Early_Blight_32.jpg', 'Early_Blight_102.jpg', 'Early_Blight_46.jpg', 'Early_Blight_69.jpg', 'Early_Blight_19.jpg', 'Early_Blight_70.jpg', 'Early_Blight_109.jpg', 'Early_Blight_99.jpg', 'Early_Blight_22.jpg', 'Early_Blight_156.jpg', 'Early_Blight_50.jpg', 'Early_Blight_144.jpg', 'Early_Blight_95.jpg', 'Early_Blight_15.jpg', 'Early_Blight_98.jpg', 'Early_Blight_119.jpg', 'Early_Blight_158.jpg', 'Early_Blight_31.jpg', 'Early_Blight_80.jpg', 'Early_Blight_153.jpg', 'Early_Blight_152.jpg', 'Early_Blight_71.jpg', 'Early_Blight_5.jpg', 'Early_Blight_120.jpg', 'Early_Blight_85.jpg', 'Early_Blight_14.jpg', 'Early_Blight_28.jpg', 'Early_Blight_104.jpg', 'Early_Blight_72.jpg', 'Early_Blight_94.jpg', 'Early_Blight_67.jpg', 'Early_Blight_159.jpg', 'Early_Blight_150.jpg', 'Early_Blight_8.jpg', 'Early_Blight_154.jpg', 'Early_Blight_97.jpg', 'Early_Blight_87.jpg', 'Early_Blight_24.jpg', 'Early_Blight_132.jpg', 'Early_Blight_136.jpg', 'Early_Blight_134.jpg', 'Early_Blight_84.jpg', 'Early_Blight_65.jpg', 'Early_Blight_53.jpg', 'Early_Blight_128.jpg', 'Early_Blight_55.jpg', 'Early_Blight_91.jpg', 'Early_Blight_131.jpg', 'Early_Blight_58.jpg', 'Early_Blight_135.jpg', 'Early_Blight_17.jpg', 'Early_Blight_25.jpg', 'Early_Blight_105.jpg', 'Early_Blight_141.jpg', 'Early_Blight_57.jpg', 'Early_Blight_18.jpg', 'Early_Blight_56.jpg', 'Early_Blight_54.jpg', 'Early_Blight_77.jpg', 'Early_Blight_47.jpg', 'Early_Blight_117.jpg', 'Early_Blight_124.jpg', 'Early_Blight_86.jpg', 'Early_Blight_161.jpg', 'Early_Blight_9.jpg', 'Early_Blight_90.jpg', 'Early_Blight_78.jpg', 'Early_Blight_147.jpg', 'Early_Blight_101.jpg', 'Early_Blight_60.jpg', 'Early_Blight_113.jpg', 'Early_Blight_45.jpg', 'Early_Blight_110.jpg', 'Early_Blight_37.jpg', 'Early_Blight_62.jpg', 'Early_Blight_51.jpg', 'Early_Blight_11.jpg', 'Early_Blight_127.jpg', 'Early_Blight_76.jpg', 'Early_Blight_23.jpg', 'Early_Blight_149.jpg', 'Early_Blight_151.jpg', 'Early_Blight_93.jpg', 'Early_Blight_48.jpg', 'Early_Blight_6.jpg', 'Early_Blight_155.jpg', 'Early_Blight_100.jpg', 'Early_Blight_64.jpg', 'Early_Blight_142.jpg', 'Early_Blight_122.jpg', 'Early_Blight_111.jpg', 'Early_Blight_30.jpg', 'Early_Blight_143.jpg', 'Early_Blight_96.jpg', 'Early_Blight_126.jpg', 'Early_Blight_3.jpg', 'Early_Blight_42.jpg', 'Early_Blight_33.jpg', 'Early_Blight_2.jpg', 'Early_Blight_106.jpg', 'Early_Blight_88.jpg', 'Early_Blight_12.jpg', 'Early_Blight_63.jpg', 'Early_Blight_43.jpg', 'Early_Blight_39.jpg', 'Early_Blight_40.jpg', 'Early_Blight_66.jpg', 'Early_Blight_49.jpg', 'Early_Blight_38.jpg', 'Early_Blight_52.jpg', 'Early_Blight_79.jpg', 'Early_Blight_59.jpg', 'Early_Blight_74.jpg', 'Early_Blight_115.jpg', 'Early_Blight_162.jpg', 'Early_Blight_10.jpg', 'Early_Blight_138.jpg', 'Early_Blight_16.jpg', 'Early_Blight_145.jpg', 'Early_Blight_34.jpg', 'Early_Blight_130.jpg', 'Early_Blight_148.jpg', 'Early_Blight_92.jpg', 'Early_Blight_7.jpg', 'Early_Blight_36.jpg', 'Early_Blight_68.jpg', 'Early_Blight_21.jpg', 'Early_Blight_103.jpg', 'Early_Blight_75.jpg', 'Early_Blight_146.jpg', 'Early_Blight_108.jpg', 'Early_Blight_160.jpg', 'Early_Blight_41.jpg']
# --------------------
# Root: /content/extracted_files/PLD_3_Classes_256/Training
# Directories: ['Healthy', 'Late_Blight', 'Early_Blight']
# Files: []
# --------------------
# Root: /content/extracted_files/PLD_3_Classes_256/Training/Healthy
# Directories: []
# Files: ['Healthy_184.jpg', 'Healthy_577.jpg', 'Healthy_561.jpg', 'Healthy_222.jpg', 'Healthy_323.jpg', 'Healthy_132.jpg', 'Healthy_226.jpg', 'Healthy_277.jpg', 'Healthy_634.jpg', 'Healthy_488.jpg', 'Healthy_80.jpg', 'Healthy_472.jpg', 'Healthy_445.jpg', 'Healthy_26.jpg', 'Healthy_786.jpg', 'Healthy_761.jpg', 'Healthy_262.jpg', 'Healthy_2.jpg', 'Healthy_122.jpg', 'Healthy_153.jpg', 'Healthy_326.jpg', 'Healthy_580.jpg', 'Healthy_691.jpg', 'Healthy_230.jpg', 'Healthy_306.jpg', 'Healthy_650.jpg', 'Healthy_373.jpg', 'Healthy_171.jpg', 'Healthy_743.jpg', 'Healthy_541.jpg', 'Healthy_595.jpg', 'Healthy_284.jpg', 'Healthy_594.jpg', 'Healthy_739.jpg', 'Healthy_179.jpg', 'Healthy_19.jpg', 'Healthy_408.jpg', 'Healthy_698.jpg', 'Healthy_127.jpg', 'Healthy_588.jpg', 'Healthy_130.jpg', 'Healthy_808.jpg', 'Healthy_385.jpg', 'Healthy_328.jpg', 'Healthy_55.jpg', 'Healthy_771.jpg', 'Healthy_28.jpg', 'Healthy_81.jpg', 'Healthy_107.jpg', 'Healthy_206.jpg', 'Healthy_274.jpg', 'Healthy_119.jpg', 'Healthy_623.jpg', 'Healthy_794.jpg', 'Healthy_349.jpg', 'Healthy_412.jpg', 'Healthy_61.jpg', 'Healthy_487.jpg', 'Healthy_631.jpg', 'Healthy_599.jpg', 'Healthy_586.jpg', 'Healthy_359.jpg', 'Healthy_276.jpg', 'Healthy_372.jpg', 'Healthy_93.jpg', 'Healthy_416.jpg', 'Healthy_459.jpg', 'Healthy_674.jpg', 'Healthy_671.jpg', 'Healthy_318.jpg', 'Healthy_801.jpg', 'Healthy_136.jpg', 'Healthy_379.jpg', 'Healthy_234.jpg', 'Healthy_413.jpg', 'Healthy_12.jpg', 'Healthy_467.jpg', 'Healthy_374.jpg', 'Healthy_470.jpg', 'Healthy_351.jpg', 'Healthy_254.jpg', 'Healthy_126.jpg', 'Healthy_612.jpg', 'Healthy_651.jpg', 'Healthy_510.jpg', 'Healthy_423.jpg', 'Healthy_683.jpg', 'Healthy_279.jpg', 'Healthy_72.jpg', 'Healthy_690.jpg', 'Healthy_729.jpg', 'Healthy_749.jpg', 'Healthy_468.jpg', 'Healthy_111.jpg', 'Healthy_728.jpg', 'Healthy_494.jpg', 'Healthy_287.jpg', 'Healthy_354.jpg', 'Healthy_537.jpg', 'Healthy_369.jpg', 'Healthy_733.jpg', 'Healthy_397.jpg', 'Healthy_532.jpg', 'Healthy_475.jpg', 'Healthy_670.jpg', 'Healthy_185.jpg', 'Healthy_448.jpg', 'Healthy_579.jpg', 'Healthy_421.jpg', 'Healthy_152.jpg', 'Healthy_715.jpg', 'Healthy_49.jpg', 'Healthy_567.jpg', 'Healthy_386.jpg', 'Healthy_322.jpg', 'Healthy_23.jpg', 'Healthy_621.jpg', 'Healthy_191.jpg', 'Healthy_478.jpg', 'Healthy_582.jpg', 'Healthy_789.jpg', 'Healthy_592.jpg', 'Healthy_725.jpg', 'Healthy_286.jpg', 'Healthy_629.jpg', 'Healthy_394.jpg', 'Healthy_17.jpg', 'Healthy_804.jpg', 'Healthy_79.jpg', 'Healthy_625.jpg', 'Healthy_556.jpg', 'Healthy_316.jpg', 'Healthy_649.jpg', 'Healthy_30.jpg', 'Healthy_791.jpg', 'Healthy_814.jpg', 'Healthy_310.jpg', 'Healthy_436.jpg', 'Healthy_370.jpg', 'Healthy_569.jpg', 'Healthy_196.jpg', 'Healthy_463.jpg', 'Healthy_646.jpg', 'Healthy_593.jpg', 'Healthy_795.jpg', 'Healthy_784.jpg', 'Healthy_213.jpg', 'Healthy_348.jpg', 'Healthy_785.jpg', 'Healthy_590.jpg', 'Healthy_391.jpg', 'Healthy_656.jpg', 'Healthy_719.jpg', 'Healthy_483.jpg', 'Healthy_704.jpg', 'Healthy_637.jpg', 'Healthy_640.jpg', 'Healthy_65.jpg', 'Healthy_246.jpg', 'Healthy_544.jpg', 'Healthy_60.jpg', 'Healthy_76.jpg', 'Healthy_499.jpg', 'Healthy_150.jpg', 'Healthy_161.jpg', 'Healthy_250.jpg', 'Healthy_745.jpg', 'Healthy_753.jpg', 'Healthy_458.jpg', 'Healthy_696.jpg', 'Healthy_330.jpg', 'Healthy_180.jpg', 'Healthy_63.jpg', 'Healthy_120.jpg', 'Healthy_13.jpg', 'Healthy_346.jpg', 'Healthy_547.jpg', 'Healthy_229.jpg', 'Healthy_676.jpg', 'Healthy_154.jpg', 'Healthy_617.jpg', 'Healthy_140.jpg', 'Healthy_237.jpg', 'Healthy_353.jpg', 'Healthy_311.jpg', 'Healthy_815.jpg', 'Healthy_542.jpg', 'Healthy_66.jpg', 'Healthy_158.jpg', 'Healthy_658.jpg', 'Healthy_661.jpg', 'Healthy_343.jpg', 'Healthy_788.jpg', 'Healthy_46.jpg', 'Healthy_723.jpg', 'Healthy_469.jpg', 'Healthy_699.jpg', 'Healthy_644.jpg', 'Healthy_344.jpg', 'Healthy_216.jpg', 'Healthy_486.jpg', 'Healthy_538.jpg', 'Healthy_37.jpg', 'Healthy_187.jpg', 'Healthy_90.jpg', 'Healthy_137.jpg', 'Healthy_428.jpg', 'Healthy_576.jpg', 'Healthy_89.jpg', 'Healthy_403.jpg', 'Healthy_645.jpg', 'Healthy_5 ...
# --------------------
# Root: /content/extracted_files/PLD_3_Classes_256/Training/Late_Blight
# Directories: []
# Files: ['Late_Blight_694.jpg', 'Late_Blight_473.jpg', 'Late_Blight_660.jpg', 'Late_Blight_159.jpg', 'Late_Blight_566.jpg', 'Late_Blight_154.jpg', 'Late_Blight_449.jpg', 'Late_Blight_94.jpg', 'Late_Blight_664.jpg', 'Late_Blight_983.jpg', 'Late_Blight_842.jpg', 'Late_Blight_483.jpg', 'Late_Blight_301.jpg', 'Late_Blight_427.jpg', 'Late_Blight_506.jpg', 'Late_Blight_87.jpg', 'Late_Blight_1062.jpg', 'Late_Blight_443.jpg', 'Late_Blight_883.jpg', 'Late_Blight_793.jpg', 'Late_Blight_516.jpg', 'Late_Blight_152.jpg', 'Late_Blight_65.jpg', 'Late_Blight_381.jpg', 'Late_Blight_884.jpg', 'Late_Blight_83.jpg', 'Late_Blight_176.jpg', 'Late_Blight_588.jpg', 'Late_Blight_1050.jpg', 'Late_Blight_156.jpg', 'Late_Blight_17.jpg', 'Late_Blight_358.jpg', 'Late_Blight_716.jpg', 'Late_Blight_823.jpg', 'Late_Blight_944.jpg', 'Late_Blight_938.jpg', 'Late_Blight_964.jpg', 'Late_Blight_896.jpg', 'Late_Blight_794.jpg', 'Late_Blight_43.jpg', 'Late_Blight_1117.jpg', 'Late_Blight_834.jpg', 'Late_Blight_844.jpg', 'Late_Blight_482.jpg', 'Late_Blight_765.jpg', 'Late_Blight_1040.jpg', 'Late_Blight_599.jpg', 'Late_Blight_479.jpg', 'Late_Blight_758.jpg', 'Late_Blight_305.jpg', 'Late_Blight_1035.jpg', 'Late_Blight_727.jpg', 'Late_Blight_1025.jpg', 'Late_Blight_202.jpg', 'Late_Blight_706.jpg', 'Late_Blight_460.jpg', 'Late_Blight_695.jpg', 'Late_Blight_464.jpg', 'Late_Blight_114.jpg', 'Late_Blight_650.jpg', 'Late_Blight_871.jpg', 'Late_Blight_881.jpg', 'Late_Blight_923.jpg', 'Late_Blight_334.jpg', 'Late_Blight_733.jpg', 'Late_Blight_136.jpg', 'Late_Blight_653.jpg', 'Late_Blight_151.jpg', 'Late_Blight_71.jpg', 'Late_Blight_563.jpg', 'Late_Blight_223.jpg', 'Late_Blight_157.jpg', 'Late_Blight_528.jpg', 'Late_Blight_848.jpg', 'Late_Blight_843.jpg', 'Late_Blight_735.jpg', 'Late_Blight_696.jpg', 'Late_Blight_615.jpg', 'Late_Blight_1080.jpg', 'Late_Blight_548.jpg', 'Late_Blight_182.jpg', 'Late_Blight_370.jpg', 'Late_Blight_338.jpg', 'Late_Blight_915.jpg', 'Late_Blight_712.jpg', 'Late_Blight_46.jpg', 'Late_Blight_311.jpg', 'Late_Blight_407.jpg', 'Late_Blight_867.jpg', 'Late_Blight_101.jpg', 'Late_Blight_590.jpg', 'Late_Blight_777.jpg', 'Late_Blight_432.jpg', 'Late_Blight_920.jpg', 'Late_Blight_924.jpg', 'Late_Blight_16.jpg', 'Late_Blight_704.jpg', 'Late_Blight_423.jpg', 'Late_Blight_1070.jpg', 'Late_Blight_858.jpg', 'Late_Blight_1118.jpg', 'Late_Blight_497.jpg', 'Late_Blight_902.jpg', 'Late_Blight_539.jpg', 'Late_Blight_730.jpg', 'Late_Blight_307.jpg', 'Late_Blight_1004.jpg', 'Late_Blight_48.jpg', 'Late_Blight_1060.jpg', 'Late_Blight_412.jpg', 'Late_Blight_244.jpg', 'Late_Blight_242.jpg', 'Late_Blight_296.jpg', 'Late_Blight_720.jpg', 'Late_Blight_446.jpg', 'Late_Blight_1094.jpg', 'Late_Blight_816.jpg', 'Late_Blight_748.jpg', 'Late_Blight_313.jpg', 'Late_Blight_13.jpg', 'Late_Blight_550.jpg', 'Late_Blight_722.jpg', 'Late_Blight_755.jpg', 'Late_Blight_995.jpg', 'Late_Blight_602.jpg', 'Late_Blight_939.jpg', 'Late_Blight_1073.jpg', 'Late_Blight_363.jpg', 'Late_Blight_873.jpg', 'Late_Blight_752.jpg', 'Late_Blight_1044.jpg', 'Late_Blight_943.jpg', 'Late_Blight_742.jpg', 'Late_Blight_27.jpg', 'Late_Blight_1084.jpg', 'Late_Blight_331.jpg', 'Late_Blight_25.jpg', 'Late_Blight_711.jpg', 'Late_Blight_836.jpg', 'Late_Blight_332.jpg', 'Late_Blight_1011.jpg', 'Late_Blight_70.jpg', 'Late_Blight_189.jpg', 'Late_Blight_1092.jpg', 'Late_Blight_1091.jpg', 'Late_Blight_467.jpg', 'Late_Blight_906.jpg', 'Late_Blight_790.jpg', 'Late_Blight_820.jpg', 'Late_Blight_206.jpg', 'Late_Blight_918.jpg', 'Late_Blight_963.jpg', 'Late_Blight_257.jpg', 'Late_Blight_359.jpg', 'Late_Blight_774.jpg', 'Late_Blight_292.jpg', 'Late_Blight_784.jpg', 'Late_Blight_60.jpg', 'Late_Blight_717.jpg', 'Late_Blight_895.jpg', 'Late_Blight_555.jpg', 'Late_Blight_372.jpg', 'Late_Blight_723.jpg', 'Late_Blight_1076.jpg', 'Late_Blight_1120.jpg', 'Late_Blight_430.jpg', 'Late_Blight_36.jpg', 'Late_Blight_362.jpg', 'Late_Blight_795.jpg', 'Late_Blight_674.jpg', 'Late_Blight_81.jpg', 'Late_Blight_595.jpg', 'Late_Blight_764.jpg', 'Late_Blig ...
# --------------------
# Root: /content/extracted_files/PLD_3_Classes_256/Training/Early_Blight
# Directories: []
# Files: ['Early_Blight_725.jpg', 'Early_Blight_116.jpg', 'Early_Blight_83.jpg', 'Early_Blight_35.jpg', 'Early_Blight_1090.jpg', 'Early_Blight_621.jpg', 'Early_Blight_13.jpg', 'Early_Blight_1005.jpg', 'Early_Blight_1095.jpg', 'Early_Blight_691.jpg', 'Early_Blight_1025.jpg', 'Early_Blight_474.jpg', 'Early_Blight_1088.jpg', 'Early_Blight_157.jpg', 'Early_Blight_4.jpg', 'Early_Blight_194.jpg', 'Early_Blight_1171.jpg', 'Early_Blight_717.jpg', 'Early_Blight_1106.jpg', 'Early_Blight_635.jpg', 'Early_Blight_441.jpg', 'Early_Blight_570.jpg', 'Early_Blight_89.jpg', 'Early_Blight_836.jpg', 'Early_Blight_843.jpg', 'Early_Blight_947.jpg', 'Early_Blight_139.jpg', 'Early_Blight_769.jpg', 'Early_Blight_870.jpg', 'Early_Blight_229.jpg', 'Early_Blight_930.jpg', 'Early_Blight_758.jpg', 'Early_Blight_996.jpg', 'Early_Blight_398.jpg', 'Early_Blight_614.jpg', 'Early_Blight_1160.jpg', 'Early_Blight_123.jpg', 'Early_Blight_834.jpg', 'Early_Blight_807.jpg', 'Early_Blight_903.jpg', 'Early_Blight_107.jpg', 'Early_Blight_291.jpg', 'Early_Blight_27.jpg', 'Early_Blight_915.jpg', 'Early_Blight_745.jpg', 'Early_Blight_210.jpg', 'Early_Blight_811.jpg', 'Early_Blight_316.jpg', 'Early_Blight_82.jpg', 'Early_Blight_1.jpg', 'Early_Blight_831.jpg', 'Early_Blight_696.jpg', 'Early_Blight_494.jpg', 'Early_Blight_331.jpg', 'Early_Blight_446.jpg', 'Early_Blight_491.jpg', 'Early_Blight_214.jpg', 'Early_Blight_327.jpg', 'Early_Blight_1000.jpg', 'Early_Blight_344.jpg', 'Early_Blight_121.jpg', 'Early_Blight_528.jpg', 'Early_Blight_945.jpg', 'Early_Blight_880.jpg', 'Early_Blight_1287.jpg', 'Early_Blight_399.jpg', 'Early_Blight_684.jpg', 'Early_Blight_114.jpg', 'Early_Blight_1181.jpg', 'Early_Blight_564.jpg', 'Early_Blight_1104.jpg', 'Early_Blight_1289.jpg', 'Early_Blight_513.jpg', 'Early_Blight_1049.jpg', 'Early_Blight_576.jpg', 'Early_Blight_44.jpg', 'Early_Blight_418.jpg', 'Early_Blight_1214.jpg', 'Early_Blight_29.jpg', 'Early_Blight_20.jpg', 'Early_Blight_522.jpg', 'Early_Blight_822.jpg', 'Early_Blight_875.jpg', 'Early_Blight_764.jpg', 'Early_Blight_998.jpg', 'Early_Blight_234.jpg', 'Early_Blight_983.jpg', 'Early_Blight_981.jpg', 'Early_Blight_951.jpg', 'Early_Blight_574.jpg', 'Early_Blight_1190.jpg', 'Early_Blight_1147.jpg', 'Early_Blight_207.jpg', 'Early_Blight_302.jpg', 'Early_Blight_278.jpg', 'Early_Blight_129.jpg', 'Early_Blight_1296.jpg', 'Early_Blight_283.jpg', 'Early_Blight_478.jpg', 'Early_Blight_1053.jpg', 'Early_Blight_1142.jpg', 'Early_Blight_768.jpg', 'Early_Blight_1060.jpg', 'Early_Blight_747.jpg', 'Early_Blight_921.jpg', 'Early_Blight_357.jpg', 'Early_Blight_1136.jpg', 'Early_Blight_1265.jpg', 'Early_Blight_318.jpg', 'Early_Blight_1285.jpg', 'Early_Blight_73.jpg', 'Early_Blight_955.jpg', 'Early_Blight_168.jpg', 'Early_Blight_1073.jpg', 'Early_Blight_549.jpg', 'Early_Blight_906.jpg', 'Early_Blight_978.jpg', 'Early_Blight_81.jpg', 'Early_Blight_586.jpg', 'Early_Blight_1226.jpg', 'Early_Blight_797.jpg', 'Early_Blight_715.jpg', 'Early_Blight_164.jpg', 'Early_Blight_1257.jpg', 'Early_Blight_1154.jpg', 'Early_Blight_566.jpg', 'Early_Blight_697.jpg', 'Early_Blight_281.jpg', 'Early_Blight_1078.jpg', 'Early_Blight_266.jpg', 'Early_Blight_1192.jpg', 'Early_Blight_1050.jpg', 'Early_Blight_1103.jpg', 'Early_Blight_269.jpg', 'Early_Blight_993.jpg', 'Early_Blight_309.jpg', 'Early_Blight_1270.jpg', 'Early_Blight_868.jpg', 'Early_Blight_746.jpg', 'Early_Blight_340.jpg', 'Early_Blight_698.jpg', 'Early_Blight_1243.jpg', 'Early_Blight_1175.jpg', 'Early_Blight_1216.jpg', 'Early_Blight_1125.jpg', 'Early_Blight_827.jpg', 'Early_Blight_876.jpg', 'Early_Blight_137.jpg', 'Early_Blight_231.jpg', 'Early_Blight_929.jpg', 'Early_Blight_233.jpg', 'Early_Blight_814.jpg', 'Early_Blight_242.jpg', 'Early_Blight_750.jpg', 'Early_Blight_795.jpg', 'Early_Blight_999.jpg', 'Early_Blight_352.jpg', 'Early_Blight_630.jpg', 'Early_Blight_871.jpg', 'Early_Blight_928.jpg', 'Early_Blight_356.jpg', 'Early_Blight_336.jpg', 'Early_Blight_516.jpg', 'Early_Blight_894.jpg', 'Early_Blight_1274.jpg', 'Early_Bl ...
# --------------------

# %% [markdown]
# # Extracting only potato dataset

# %%
# !cp -rf ../input/plant-village/PlantVillage/Potato___Early_blight ./Potato___Early_blight

# %%
# !cp -rf ../input/plant-village/PlantVillage/Potato___Late_blight ./Potato___Late_blight

# %%
# !cp -rf ../input/plant-village/PlantVillage/Potato___healthy ./Potato___healthy

# %%
Current_Dir = os.getcwd()
dataset_dir = pathlib.Path(Current_Dir)
print(dataset_dir)
# Out:
# /content

# %%
#Global initialization of some imp variables
Image_Size = 256
Batch_Size = 32
Channels = 3
Epochs = 40

# %%
#yields batches of images from the subdirectories class_a , class_b and class_c
#together with labels 0 , 1 and 2 (0, 1, 2 corresponding to classes class_a , class_b and class_c respectively )
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    dataset_dir, batch_size = Batch_Size, image_size = (Image_Size, Image_Size), shuffle = True)
# Out:
# Found 8376 files belonging to 5 classes.

# %%
#Folders(classes) in 'Dataset' directory
class_name = dataset.class_names
class_name
# Out:
# ['Potato___Early_blight',
#  'Potato___Late_blight',
#  'Potato___healthy',
#  'extracted_files',
#  'sample_data']

# %%
len(dataset) # Number of Batches = (total number of files belonging to all classes / Batch_Size)
# Out:
# 262

# %%
print(dataset) #prints Elements in dataset: here 1st element is image and 2nd index of that image.
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
# Plotting the image
plt.figure(figsize = (15,15))
# dataset.take(count) : Creates a Dataset with at most 'count' elements(batch) from the dataset
for image, label in dataset.take(1):
    for i in range(12):
        plt.subplot(3, 4, i+1) # many plots at a time =>subpots
        plt.imshow(image[i].numpy().astype('uint8')) #converting all data of image into numpy and than to intiger type as they were in float.
        plt.title(class_name[label[i]])  # title of the class_name of image
        plt.axis("off") # Hide the values of graph

# %% [markdown]
# # Splitting Dataset

# %%
# Function for Splitting the data
def split_dataset(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):

    if shuffle:
        ds = ds.shuffle(shuffle_size, seed = 10)

    ds_size = len(ds)
    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)

    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)

    return train_ds, val_ds, test_ds

# %%
train_data, val_data, test_data = split_dataset(dataset)

# %%
print("Size of Data is :{0} \nBatch size of Training Data is :{1}\nBatch size of Validation Data is :{2} \nBatch size of Testing Data is :{3} " .format(len(dataset), len(train_data), len(val_data), len(test_data)))
# Out:
# Size of Data is :262
# Batch size of Training Data is :209
# Batch size of Validation Data is :26
# Batch size of Testing Data is :27

# %%
# caching,shuffle and prefetching the data
train_ds = train_data.cache().shuffle(100).prefetch(buffer_size = tf.data.AUTOTUNE)
val_ds = val_data.cache().shuffle(100).prefetch(buffer_size = tf.data.AUTOTUNE)
test_ds = test_data.cache().shuffle(100).prefetch(buffer_size = tf.data.AUTOTUNE)

# %% [markdown]
# # Data Pre-processing

# %%
# Image Preprocessing : Rescaling and Resizing
resize_and_rescale = tf.keras.Sequential([
    layers.experimental.preprocessing.Resizing(Image_Size, Image_Size),
    layers.experimental.preprocessing.Rescaling(1.0/255)
])

# %%
# Data augmentation by flipping and rotating existing images
data_augmentation = tf.keras.Sequential([
    layers.experimental.preprocessing.RandomFlip(mode="horizontal_and_vertical"),
    layers.experimental.preprocessing.RandomRotation(factor = 0.5)
])

# %% [markdown]
# # Model Building

# %%
# Creating Convolution layer
input_shape = (Batch_Size, Image_Size, Image_Size, Channels)
model = models.Sequential([
    resize_and_rescale,
    data_augmentation,
    layers.Conv2D(filters = 16, kernel_size = (3,3), activation = 'relu', input_shape = input_shape),
    layers.MaxPool2D((2,2)),
    layers.Conv2D(64, (3,3), activation = 'relu'),
    layers.MaxPool2D((2,2)),
    layers.Conv2D(128, (3,3), activation = 'relu'),
    layers.MaxPool2D((2,2)),
    layers.Conv2D(64, (3,3), activation = 'relu'),
    layers.MaxPool2D((2,2)),
    layers.Conv2D(128, (3,3), activation = 'relu'),
    layers.MaxPool2D((2,2)),
    layers.Conv2D(64, (3,3), activation = 'relu'),
    layers.MaxPool2D((2,2)),
    layers.Flatten(),
    layers.Dense(128, activation = 'relu'),
    layers.Dense(64, activation = 'softmax'),

])


model.build(input_shape = input_shape)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (32, 256, 256, 3)         0
#
#  sequential_1 (Sequential)   (32, 256, 256, 3)         0
#
#  conv2d (Conv2D)             (32, 254, 254, 16)        448
#
#  max_pooling2d (MaxPooling2  (32, 127, 127, 16)        0
#  D)
#
#  conv2d_1 (Conv2D)           (32, 125, 125, 64)        9280
#
#  max_pooling2d_1 (MaxPoolin  (32, 62, 62, 64)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (32, 60, 60, 128)         73856
#
#  max_pooling2d_2 (MaxPoolin  (32, 30, 30, 128)         0
#  g2D)
#
#  conv2d_3 (Conv2D)           (32, 28, 28, 64)          73792
#
#  max_pooling2d_3 (MaxPoolin  (32, 14, 14, 64)          0
#  g2D)
#
#  conv2d_4 (Conv2D)           (32, 12, 12, 128)         73856
#
#  max_pooling2d_4 (MaxPoolin  (32, 6, 6, 128)           0
#  g2D)
#
#  conv2d_5 (Conv2D)           (32, 4, 4, 64)            73792
#
#  max_pooling2d_5 (MaxPoolin  (32, 2, 2, 64)            0
#  g2D)
#
#  flatten (Flatten)           (32, 256)                 0
#
#  dense (Dense)               (32, 128)                 32896
#
#  dense_1 (Dense)             (32, 64)                  8256
#
# =================================================================
# Total params: 346176 (1.32 MB)
# Trainable params: 346176 (1.32 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Optimizing the model 'SparseCategoricalCrossentropy'=>as there are many categorical classes of data
model.compile(
    optimizer = 'adam',
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits = False),
    metrics = ['accuracy'])

# %%
#Fit the model with training data and also pass validation data
history = model.fit(
train_data, epochs = Epochs, batch_size = Batch_Size, verbose = 1, validation_data = val_data)
# Out:
# Epoch 1/40
# 209/209 [==============================] - ETA: 0s - loss: 0.6171 - accuracy: 0.7596

# %%
scores = model.evaluate(train_data)

# %%
history

# %%
history.params

# %%
history.history.keys()

# %% [markdown]
# # Analyzing the Output

# %%
# Getting the model history to analyse
train_loss = history.history['loss']
train_acc = history.history['accuracy']

val_loss = history.history['val_loss']
val_acc = history.history['val_accuracy']

# %%
#graphs for accuracy and loss of training and validation data
plt.figure(figsize = (15,15))
plt.subplot(2,3,1)
plt.plot(range(Epochs), train_acc, label = 'Training Accuracy')
plt.plot(range(Epochs), val_acc, label = 'Validation Accuracy')
plt.legend(loc = 'lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2,3,2)
plt.plot(range(Epochs), train_loss, label = 'Training Loss')
plt.plot(range(Epochs), val_loss, label = 'Validation Loss')
plt.legend(loc = 'upper right')
plt.title('Training and Validation Loss')

# %%
#plotting image
for batch_image, batch_label in train_data.take(1):
    first_image = batch_image[0].numpy().astype('uint8')
    first_label = class_name[batch_label[0]]

    print('First Image of batch to predict :')
    plt.imshow(first_image)
    print('Actual label : ', first_label)

    batch_prediction = model.predict(batch_image)
    print('Predicted label : ', class_name[np.argmax(batch_prediction[0])])
    plt.axis('off')

# %%
# plotting batch of images with its actual label, predicted label and confidence
plt.figure(figsize = (16,16))
for batch_image, batch_label in train_data.take(1):
    for i in range(9):
        ax = plt.subplot(3,3,i+1)
        image = batch_image[i].numpy().astype('uint8')
        label = class_name[batch_label[i]]

        plt.imshow(image)

        batch_prediction = model.predict(batch_image)
        predicted_class = class_name[np.argmax(batch_prediction[i])]
        confidence = round(np.max(batch_prediction[i]) * 100, 2)

        plt.title(f'Actual : {label},\n Prediction : {predicted_class},\n Confidence : {confidence}%')

        plt.axis('off')

# %% [markdown]
# ### The Model shows accuracy > 97%
